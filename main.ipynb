# %%
# Scarica TaBERT_Base_(k=3)
# !gdown "https://drive.google.com/uc?id=1NPxbGhwJF1uU9EC18YFsEZYE-IQR7ZLj"
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1NPxbGhwJF1uU9EC18YFsEZYE-IQR7ZLj
# From (redirected): https://drive.google.com/uc?id=1NPxbGhwJF1uU9EC18YFsEZYE-IQR7ZLj&confirm=t&uuid=9f4b644c-c191-4a60-9eb1-387fdfc15d79
# To: d:\NeuralTabb\neuralTabb\tabert_base_k3.tar.gz
#
#   0%|          | 0.00/245M [00:00<?, ?B/s]
#   0%|          | 1.05M/245M [00:00<00:42, 5.70MB/s]
#   1%|          | 2.10M/245M [00:00<00:45, 5.35MB/s]
#   1%|▏         | 3.15M/245M [00:00<00:45, 5.33MB/s]
#   2%|▏         | 4.19M/245M [00:00<00:45, 5.33MB/s]
#   2%|▏         | 5.24M/245M [00:00<00:44, 5.44MB/s]
#   3%|▎         | 6.29M/245M [00:01<00:39, 6.10MB/s]
#   3%|▎         | 7.34M/245M [00:01<00:38, 6.24MB/s]
#   3%|▎         | 8.39M/245M [00:01<00:34, 6.82MB/s]
#   4%|▍         | 9.44M/245M [00:01<00:34, 6.88MB/s]
#   4%|▍         | 10.5M/245M [00:01<00:32, 7.16MB/s]
#   5%|▍         | 11.5M/245M [00:01<00:30, 7.64MB/s]
#   5%|▌         | 12.6M/245M [00:01<00:29, 7.90MB/s]
# ...

# %%
import pandas as pd

# !pip install openpyxl
# Out:
# ...
#   Obtaining dependency information for openpyxl from https://files.pythonhosted.org/packages/c0/da/977ded879c29cbd04de313843e76868e6e13408a94ed6b987245dc7c8506/openpyxl-3.1.5-py2.py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for et-xmlfile from https://files.pythonhosted.org/packages/c1/8b/5fe2cc11fee489817272089c4203e679c63b570a5aaeb18d852ae3cbba6a/et_xmlfile-2.0.0-py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/250.9 kB ? eta -:--:--
#    - -------------------------------------- 10.2/250.9 kB ? eta -:--:--
#    ---------------- ----------------------- 102.4/250.9 kB 1.2 MB/s eta 0:00:01
#    ---------------------------------------- 250.9/250.9 kB 2.2 MB/s eta 0:00:00
# ...
# [notice] A new release of pip is available: 23.2.1 -> 25.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
for i in range (0,5):
    print("Ciao")
# Out:
# Ciao
# Ciao
# Ciao
# Ciao
# Ciao

# %%
# Specifica il percorso del file Excel
file_path = "dataset\Online Retail.xlsx"

# Carica il file Excel
df = pd.read_excel(file_path)

# Stampa tutte le righe
print(df.head())
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
# !pip install --editable
# Out:
# Usage:
#   pip install [options] <requirement specifier> [package-index-options] ...
#   pip install [options] -r <requirements file> [package-index-options] ...
#   pip install [options] [-e] <vcs project url> ...
#   pip install [options] [-e] <local project path> ...
#   pip install [options] <archive url/path> ...
#
# --editable option requires 1 argument

# %%
from table_bert import TableBertModel, Column, Table

print(df.columns)
# Definisci le colonne della tabella
# Out:
# WARNING:root:You are using the old version of `pytorch_pretrained_bert`
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from table_bert import TableBertModel, Column, Table
#       3 print(df.columns)
#       4 # Definisci le colonne della tabella
#
# File D:\NeuralTabb\neuralTabb\TaBERT\table_bert\__init__.py:8
#       1 #!/usr/bin/env python3
#       2 # Copyright (c) Facebook, Inc. and its affiliates.
#       3 # All rights reserved.
#       4 #
#       5 # This source code is licensed under the license found in the
#       6 # LICENSE file in the root directory of this source tree.
# ----> 8 from table_bert.config import TableBertConfig
#       9 from table_bert.table_bert import TableBertModel
#      10 from table_bert.vanilla_table_bert import VanillaTableBert
#
# File D:\NeuralTabb\neuralTabb\TaBERT\table_bert\config.py:22
# ...

# %%
columns = [
    Column('InvoiceNo', 'number'),
    Column('StockCode', 'number'),
    Column('Description', 'text'),
    Column('Quantity', 'number'),
    Column('InvoiceDate', 'number'),
    Column('UnitPrice', 'number'),
    Column('CustomerID', 'number'),
    Column('Country', 'text')
]
